# %%
print("Hello, World!")
print("I just started git essentials course.")

name = 'Taseer'
if name == "Taseer":
  print("It's Taseer Here")
else:
  print("Taseer is busy")

print("Thanks for the Pull")
# Out:
# Hello, World!
# I just started git essentials course.
# It's Taseer Here
# Thanks for the Pull
